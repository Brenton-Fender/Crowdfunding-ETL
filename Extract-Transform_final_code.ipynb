# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backer_info = pd.read_csv("..\\Crowdfunding-ETL\\backer_info.csv")

backer_info
# Out:
#      backer_id  cf_id              name                  email
# 0        av166    968    Angelo Vincent      avincent@live.com
# 1        ha127    563     Hubert Arnold     harnold@yandex.com
# 2        lg794     65      Loris Goulet     lgoulet@yandex.com
# 3        tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4        lh506    563        Lexie Hunt         lhunt@live.com
# ...        ...    ...               ...                    ...
# 8170     st581     65   Serita Thebault   sthebault@yandex.com
# 8171     gf637    563   Glenn Foerstner   gfoerstner@yahoo.com
# 8172     rc983   1114       Robt Collin    rcollin@outlook.com
# 8173     cz381     65      Corina Zappa     czappa@outlook.com
# 8174     fg535     65     Freeman Gibbs     fgibbs@outlook.com
#
# [8175 rows x 4 columns]

# %%
# Get the data from the first row and convert it to a dictionary.
import json
first_row = backer_info.iloc[0]['backer_info']
converted_data = json.loads(first_row)
for k, v in converted_data.items():
    print(k,v)

# Iterate through the backers DataFrame and convert each row to a dictionary.
dict_values = []
for i, row in backer_info.iterrows():
    data = row['backer_info']
    converted_data = json.loads(data)
    # Iterate through each dictionary (row) and get the values for each row using list comprehension.
    row_values = [v for k, v in converted_data.items()]
    # Append the list of values for each row to a list. 
    dict_values.append(row_values)

# Print out the list of values for each row.
print(dict_values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'backer_info'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5848\504804577.py in <module>
#       1 # Get the data from the first row and convert it to a dictionary.
#       2 import json
# ----> 3 first_row = backer_info.iloc[0]['backer_info']
#       4 converted_data = json.loads(first_row)
#       5 for k, v in converted_data.items():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'backer_info'

# %%
# Create a backers_df DataFrame with the following columns: 'backer_id','cf_id', 'name', and 'email' 
# using the list of values lists. 
backers_df = pd.DataFrame(dict_values, columns=['backer_id','cf_id', 'name', 'email'])
backers_df.head(10)
# Out:
#   backer_id  cf_id              name                  email
# 0     av166    968    Angelo Vincent      avincent@live.com
# 1     ha127    563     Hubert Arnold     harnold@yandex.com
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506    563        Lexie Hunt         lhunt@live.com
# 5     lh382    563     Lambert Huber        lhuber@live.com
# 6     em444    563        Emmy Morin        emorin@live.com
# 7     at582   1572     Armonda Trani        atrani@live.com
# 8     id772   1911        Ilana Duke      iduke@outlook.com
# 9     lw275     65     Leigha Wright       lwright@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_df.to_csv('backer_info.csv', index=False, encoding='UTF8' )

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".

# %%
# Extract the name from the backer_info column and add it as a new column called "name".

# %%
# Extract the email from the backer_info column and add it as a new column called "email".

# %%
# Create a new DataFrame with the appropriate columns.

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   int64
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 255.6+ KB

# %%
# Convert cf_id to an integer if necessary.
backers_df['cf_id'].convert_dtypes()
backers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   int64
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 255.6+ KB

# %%
# Split the "name" column into "first_name" and "last_name" columns.
backers_df[['first_name', 'last_name']] = backers_df['name'].str.split(' ', n=1, expand=True)
backers_df
# Out:
#      backer_id  cf_id              name                  email first_name  \
# 0        av166    968    Angelo Vincent      avincent@live.com     Angelo
# 1        ha127    563     Hubert Arnold     harnold@yandex.com     Hubert
# 2        lg794     65      Loris Goulet     lgoulet@yandex.com      Loris
# 3        tb566    563  Teodora Brunelli  tbrunelli@outlook.com    Teodora
# 4        lh506    563        Lexie Hunt         lhunt@live.com      Lexie
# ...        ...    ...               ...                    ...        ...
# 8170     st581     65   Serita Thebault   sthebault@yandex.com     Serita
# 8171     gf637    563   Glenn Foerstner   gfoerstner@yahoo.com      Glenn
# 8172     rc983   1114       Robt Collin    rcollin@outlook.com       Robt
# 8173     cz381     65      Corina Zappa     czappa@outlook.com     Corina
# 8174     fg535     65     Freeman Gibbs     fgibbs@outlook.com    Freeman
#
#       last_name
# 0       Vincent
# 1        Arnold
# 2        Goulet
# 3      Brunelli
# 4          Hunt
# ...         ...
# 8170   Thebault
# 8171  Foerstner
# 8172     Collin
# 8173      Zappa
# 8174      Gibbs
#
# [8175 rows x 6 columns]

# %%
#  Drop the name column
backers_df = backers_df.drop(columns=['name'])

# Reorder the columns
backer_df = backers_df.reinderx(columns=["backer_id", "cf_id", "first_name", "last_name", "email"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5848\1483913776.py in <module>
#       3
#       4 # Reorder the columns
# ----> 5 backer_df = backers_df.reinderx(columns=["backer_id", "cf_id", "first_name", "last_name", "email"])
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'reinderx'

# %%
backers_df
# Out:
#      backer_id  cf_id                  email first_name  last_name
# 0        av166    968      avincent@live.com     Angelo    Vincent
# 1        ha127    563     harnold@yandex.com     Hubert     Arnold
# 2        lg794     65     lgoulet@yandex.com      Loris     Goulet
# 3        tb566    563  tbrunelli@outlook.com    Teodora   Brunelli
# 4        lh506    563         lhunt@live.com      Lexie       Hunt
# ...        ...    ...                    ...        ...        ...
# 8170     st581     65   sthebault@yandex.com     Serita   Thebault
# 8171     gf637    563   gfoerstner@yahoo.com      Glenn  Foerstner
# 8172     rc983   1114    rcollin@outlook.com       Robt     Collin
# 8173     cz381     65     czappa@outlook.com     Corina      Zappa
# 8174     fg535     65     fgibbs@outlook.com    Freeman      Gibbs
#
# [8175 rows x 5 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_df.to_csv('backers.csv', index=False, encoding='UTF8' )
